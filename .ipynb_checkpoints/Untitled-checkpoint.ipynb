# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# c/3R = a * x^3

x = []
y = []
z = []
a = 5

for i in range(1000):
    x.append(i-500)
    y.append(pow(x[i],3)*a)
    z.append(math.log(a,10))
print(x[0])
#lt.loglog(x,y)
plt.loglog(x,z)
plt.show()

plt.plot(x,y)
plt.show()
# Out:
# -500
