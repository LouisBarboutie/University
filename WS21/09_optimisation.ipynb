# %% [markdown]
# ## My own crappy code

# %%
import numpy as np
import matplotlib.pyplot as plt
from   mpl_toolkits.mplot3d import Axes3D

## initial constants
tInitial = 0
tFinal = 10
dt = 0.01
N = int((tFinal-tInitial)/dt) ## point amount
sigma = 10
beta = 8/3
rho = 28

## initial position
x = []
y = []
z = []
x.append(0.01)
y.append(0.02)
z.append(0.03)

xDot = []
yDot = []
zDot = []

r = []
t = []
for i in range(N):
    t.append(i*dt)
    
## x[i+1] = x[i] + dt*xDot[i]
for i in range(N):
    ## x coordinate
    xDot.append( sigma * (y[i] - x[i]) )
    x.append(x[i] + dt * xDot[i])
    
    ## y coordinate
    yDot.append(x[i]*(rho-z[i])-y[i])
    y.append(y[i]+dt*yDot[i])
    
    ## z coordinate
    zDot.append(x[i] * y[i] - beta * (z[i]))
    z.append(z[i] + dt*zDot[i])
    
    r.append(np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2))
    
    if np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2)>90:
        break

theta = np.linspace(-4 * np.pi, 4 * np.pi, N+1)

##follow a nice walk through colour space
crange = np.linspace(0,1.,len(theta))
crange = np.array([crange,  1.-crange, 0.5*crange]).transpose()

fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, color="blue",label='change this label')
#ax.scatter(x, y, z, color=crange)
ax.legend()
plt.show()

plt.plot(t,r)
plt.ylabel("r value")
plt.xlabel("time")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from   mpl_toolkits.mplot3d import Axes3D

## initial constants
tInitial = 0
tFinal = 10
dt = 0.01
N = int((tFinal-tInitial)/dt) ## point amount
sigma = 10
beta = 8/3
rho = 5

## initial position
x = []
y = []
z = []
x.append(0.01)
y.append(0.02)
z.append(0.03)

xDot = []
yDot = []
zDot = []

r = []
t = []
for i in range(N):
    t.append(i*dt)
    
    
## x[i+1] = x[i] + dt*xDot[i]
for i in range(N):
    ## x coordinate
    xDot.append( sigma * (y[i] - x[i]) )
    x.append(x[i] + dt * xDot[i])
    
    ## y coordinate
    yDot.append(x[i]*(rho-z[i])-y[i])
    y.append(y[i]+dt*yDot[i])
    
    ## z coordinate
    zDot.append(x[i] * y[i] - beta * z[i])
    z.append(z[i] + dt*zDot[i])
    
    r.append(np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2))
    
    if np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2)>90:
        break


fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, color="blue",label='change this label')
#ax.scatter(x, y, z)
ax.legend()

plt.show()

plt.plot(t,r)
plt.ylabel("r value")
plt.xlabel("time")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from   mpl_toolkits.mplot3d import Axes3D

## initial constants
tInitial = 0
tFinal = 10
dt = 0.01
N = 1000 #int((tFinal-tInitial)/dt) ## point amount
sigma = 10
beta = 8/3
rho = 40

## initial position
x = np.zeros(N+1)
y = np.zeros(N+1)
z = np.zeros(N+1)
x[0] = 0.01
y[0] = 0.02
z[0] = 0.03

xDot = np.zeros(N+1)
yDot = np.zeros(N+1)
zDot = np.zeros(N+1)

r = []
t = []
for i in range(N):
    t.append(i*dt)
    
## x[i+1] = x[i] + dt*xDot[i]
for i in range(N):
    ## x coordinate
    xDot[i]=( sigma * (y[i] - x[i]) )
    yDot[i]=(x[i] * (rho - z[i]) - y[i])
    zDot[i]=(x[i] * y[i] - beta * z[i])
    
    x[i+1] = (x[i] + dt * xDot[i])
    ## y coordinate
    
    y[i+1] = (y[i] + dt*yDot[i])
    
    ## z coordinate
    
    z[i+1] = (z[i] + dt*zDot[i])
   
    r.append(np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2))
    
    if np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2)>90:
        break


fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, color="blue",label='change this label')
#ax.scatter(x, y, z)
ax.legend()

plt.show()

plt.plot(t,r)
plt.ylabel("r value")
plt.xlabel("time")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from   mpl_toolkits.mplot3d import Axes3D

## initial constants
tInitial = 0
tFinal = 10
dt = 0.01
N = int((tFinal-tInitial)/dt) ## point amount
sigma = 10
beta = 8/3
rho = 28

## initial position
x = []
y = []
z = []
x.append(0.011)
y.append(0.02)
z.append(0.03)

xDot = []
yDot = []
zDot = []

r = []
t = []
for i in range(N):
    t.append(i*dt)
    
## x[i+1] = x[i] + dt*xDot[i]
for i in range(N):
    ## x coordinate
    xDot.append( sigma * (y[i] - x[i]) )
    x.append(x[i] + dt * xDot[i])
    
    ## y coordinate
    yDot.append(x[i]*(rho-z[i])-y[i])
    y.append(y[i]+dt*yDot[i])
    
    ## z coordinate
    zDot.append(x[i] * y[i] - beta * (z[i]))
    z.append(z[i] + dt*zDot[i])
    
    r.append(np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2))
    
    if np.sqrt(x[i+1]**2+y[i+1]**2+z[i+1]**2)>90:
        break

theta = np.linspace(-4 * np.pi, 4 * np.pi, N+1)

##follow a nice walk through colour space
crange = np.linspace(0,1.,len(theta))
crange = np.array([crange,  1.-crange, 0.5*crange]).transpose()

fig = plt.figure()
ax  = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, color="blue",label='change this label')
#ax.scatter(x, y, z, color=crange)
ax.legend()
plt.show()

plt.plot(t,r)
plt.ylabel("r value")
plt.xlabel("time")
plt.show()

# %% [markdown]
# ## Qualitative changes:
#
# it seems like that for small rho, we get a spiral. For bigger rho, we don't get a really pretty spiral, which is different for each rho. But still we get a "butterfly".
# Only the trajectory for rho=5 converges. It shouldn't converge elseway since  it is modelling a choatic system. It might look like it converges for some time, but can then suddenly become unpredecitable again.
